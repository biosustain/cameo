# %%
from cameo import load_model
from cameo.visualization import pathviz_maps, pathviz_svg, pathviz_cdf

# %% [markdown]
# ### List available maps

# %%
pathviz_maps()
# Out:
# ['Recon1_COMBINED',
#  'Recon1_LIPID_METABOLISM',
#  'iNJ661_COMBINED',
#  'iAF1260_tRNA_Charging',
#  'iAF1260_Alternate_Carbon_Sources',
#  'iAF1260_Amino_Acid_Metabolism',
#  'iAF1260_Fatty_Acid_Biosynthesis',
#  'iAF1260_Nucleotide_Metabolism',
#  'iAF1260_Cofactor_Biosynthesis',
#  'iAF1260_Lipopolysaccharide_(LPS)_Biosynthesis',
#  'iAF1260_COMBINED',
#  'iJR904_Amino_Acid_Metabolism',
#  'iAF1260_Central_Metabolism',
#  'EcoliCore_coreMap',
#  'iND750_Nucleotide_Metabolism',
#  'iND750_Amino_Acid_Metabolism',
#  'iJR904_Central_Metabolism',
#  'iJR904_Cell_Membrane_Constituents',
#  'iJR904_COMBINED',
#  'iJR904_Alternate_Carbon_Sources',
#  'iJR904_Cofactor_Biosynthesis',
#  'iJR904_Nucleotide_Metabolism',
#  'iSB619_Amino_Acid_Metabolism',
#  'iSB619_Central_Metabolism',
#  'iSB619_Oxidative_Phosphorylation',
#  'iSB619_Pentose_Phosphate',
#  'iSB619_Purine/Pyrimidine_Metabolism',
#  'iSB619_Cofactor_Biosynthesis',
#  'iSB619_Biomass',
#  'iND750_Cofactor_and_Vitamin_Biosynthesis',
#  'iAF692_Vitamin_and_Cofactor_Biosynthesis',
#  'iND750_Lipid_Metabolism',
#  'iSB619_Heme_Biosynthesis',
#  'iIT341_COMBINED',
#  'iSB619_COMBINED',
#  'iAF692_Nucleotide_Metabolism',
#  'iAF692_COMBINED',
#  'iIT341_Co-set_Order',
#  'iIT341_Central_Metabolism',
#  'Recon1_CARBOHYDRATE_METABOLISM',
#  'iAF1260_Murein_Biosynthesis_and_Recycling',
#  'iND750_COMBINED',
#  'Recon1_GLYCAN_METABOLISM',
#  'Recon1_NUCLEOTIDE_METABOLISM',
#  'Recon1_AMINO_ACID_METABOLISM',
#  'Recon1_SECONDARY_METABOLITES',
#  'Recon1_VITAMIN_&_COFACTOR_METABOLISM',
#  'Recon1_ENERGY_METABOLISM',
#  'iAF1260_Inorganic_Ion_Transport_(Inner_Membrane)',
#  '']

# %%
model = load_model('../tests/data/EcoliCore.xml')
solution = model.optimize()
non_zero_fluxes = dict((k,v) for k, v in solution.x_dict.iteritems() if abs(v) > 10**-6)

# %% [markdown]
# ### Draw a pathway (SVG)

# %%
pathviz_svg('EcoliCore_coreMap', ReactionData=non_zero_fluxes)
# Out:
# /var/folders/tf/s64p_pjs1_s0kt9sjqzxwfym0000gp/T/pathviz_svg_QEaRZq.json
# /var/folders/tf/s64p_pjs1_s0kt9sjqzxwfym0000gp/T/pathviz_svg_LzmXwf.svg

# %% [markdown]
# ### Draw a pathway (CDF)

# %%
pathviz_cdf('EcoliCore_coreMap', ReactionData=non_zero_fluxes, PlotLegends=True)
# Out:
# <iframe width=800 height=700 src="files/pathviz_cdf_embedded_7l6wEF.html" id="CDF"></iframe>

# %%
from IPython import get_ipython
ip = get_ipython()

# %%
ip.home_dir
# Out:
# u'/Users/niko'

# %%
ip.
